# %% [markdown]
# # Noise Traders as Technical Traders

# %% [markdown]
# ## Technical analysis?
#
# **from Investopedia**
#
# - Technical analysis is a trading discipline employed to evaluate securities and identify trading opportunities by analyzing statistics gathered from trading activity, such as price movement and volume.
# - Unlike fundamental analysts, who attempt to evaluate a security's intrinsic value, technical analysts focus on charts of price movement and various analytical tools to evaluate a security's strength or weakness.

# %% [markdown]
# ### Academics vs. Reality
# - Against EMH
# - Academics once scoffed at technical traders as akin to believing in voodoo dolls, but technical trading by the turn of the twenty-first century had gone mainstream.

# %%
from IPython.display import Image
Image("c:/python/images/techassociation.PNG")
  #https://cmtassociation.org/

# %% [markdown]
# -  Large pools of hedge fund money, by 2012, were invested in trading strategies solely based on past stock price histories.
#
# - News commentators saying that:
#   - “The market is forming a bottom.”
#   - “A very oversold market rallied today.”
#   - “The market broke through resistance today.”
#   - “The market dropped through support today.”
#   - “The market acts well.”
#   - “The market looks tired.”
#
#
# - Machine learning use technical analysis indicators as feature variables

# %% [markdown]
# ### Trend following noise traders
#
# - self-fulfilling aspect of trading behavior
# - consistent with the Shleifer on overoptimism or overpessimism
# - if it works then trend followers earn more return than rational traders

# %%
from IPython.display import Image
Image("c:/python/images/TrendFollwoing.PNG", height=300, width=300)

# %% [markdown]
# ### Reversal Patterns
#
# - island reversal:
#   - whenever a stock price gaps it must go back and fill in the gap, so that some future reversal in price is predicted by the island reversal phenomenon.
# - head-and-shoulders
# - Base Building

# %%
from IPython.display import Image
Image("c:/python/images/IslandGap.PNG", height=300, width=300)

# %%
from IPython.display import Image
Image("c:/python/images/headShoulder.PNG", height=300, width=300)

# %%
from IPython.display import Image
Image("c:/python/images/basebuilding.png", height=300, width=300)

# %% [markdown]
# ### Systematic Issue
#
# -  Noise trader들이 가격의 trend를 따르는 것은 무리본능(**herd mentality**)의 일종으로 보여질 수 있다.
#   - 가격이 빠르게 상승하면, 모든 사람들이 가격이 오르는 주식을 산다.
# -  EMH 지지자들은 noise trader들은 서로서로를 상쇄하는 경향이 있다고 주장한다.
#   - 대수의 법칙이 성립한다면 전체적으로 noise trader의 활동은 아무런 문제가 되지 않는다는 것이다.
#   -  그러나 noise trader들이 모두 거의 완전히 같은 행동을 한다면 앞의 주장은 더 이상 적용 될 수 없다.
#   - 즉, Noise trader들의 systematic한 거래행동은 기술적 분석이 의의가 있음을 뜻한다.
#
# - Noise trader show herding behavior?  $\Longrightarrow$  Shiller's model

# %% [markdown]
# ## Modern Finance: Hedge fund
#
# - Investment strategy is combination of fundamentals(various asset pricing) and technical analysis
#   - AI is coming of age
#
# - Typical pattern in hedge fund
#   -  Global Equity Index Value Trade
#   - Currency Value Trade
#   - Global Bond Value Trade
#   - Commodity Value Trade

# %%
from IPython.display import Image
Image("c:/python/images/HedgeFundStrategyREturn.png", height=700, width=700)
 #Asness, Moskowitz and Pedersen (2013): Y-axis: performance, X-axis: Time

# %% [markdown]
# ## Reference: Soro's boom/bust cycle

# %%
from IPython.display import Image
Image("c:/python/images/BoomBust.png", height=700, width=700)

# %% [markdown]
# ## Fundamental or technical?
#
# - In 2007, Larry Summers pointed out that
#   - "the US weak recovery is macroeconomic oddity"
#   - "before the crisis US had been indulging in a widl bout of economic excess, but few sign of excess where economists might normally have looked for them. Neither inflation nor wage growth were signalling that the economy had run up against its productive capacity"
#
# - How can we detect it? Financial Market?
#
# - In 2018 Sept., Jerome Powell, the chairman of the Federal Reserve, expressed frustration at the economy's failure to behave
#   - "Inflation may no loger be the first or best indicator of a tight labor market and rising pressure on resource utilization"
#   - "The Fed should look instead to financial markets for signs of excess"
